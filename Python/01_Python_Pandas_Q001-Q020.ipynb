# %%
import os
os.getcwd()
# Out:
# 'F:\\Project Data Master\\Python Files'

# %% [markdown]
# # Asteron Data Lab — Python/Pandas Problems 1–20
#
# Dataset: ERP Customers

# %% [markdown]
# ##1 — Load erp_customers.csv with pandas

# %%
import pandas as pd
customers = pd.read_csv(r"F:\Project Data Master\Asteron_Data_Lab_v1_Learner_Pack\raw\erp_customers.csv")
customers
# Out:
#      customer_id                    customer_name        city           state  \
# 0         C00001          Trinity Fasteners Works      Nashik     Maharashtra
# 1         C00002               Nova Fasteners Ltd   Bengaluru       Karnataka
# 2         C00003           Royal Equipments Works      Nashik     Maharashtra
# 3         C00004         Universal Equipments LLP   Ahmedabad         Gujarat
# 4         C00005           Metro Equipments Works      Bhopal  Madhya Pradesh
# ...          ...                              ...         ...             ...
# 5995      C05996            Kinetic Works Pvt Ltd        Pune     Maharashtra
# 5996      C05997         Western Tools Industries   Bengaluru       Karnataka
# 5997      C05998  Dynamic Technologies Industries  Coimbatore      Tamil Nadu
# 5998      C05999            Metro Solutions Works   Ahmedabad         Gujarat
# 5999      C06000         Western Industries Works     Chennai      Tamil Nadu
#
# ...

# %% [markdown]
# ##2. Display first 10 rows.

# %%
import pandas as pd
customers =pd.read_csv(r"F:\Project Data Master\Asteron_Data_Lab_v1_Learner_Pack\raw\erp_customers.csv")
customers.head(10)
# Out:
#   customer_id                     customer_name       city           state  \
# 0      C00001           Trinity Fasteners Works     Nashik     Maharashtra
# 1      C00002                Nova Fasteners Ltd  Bengaluru       Karnataka
# 2      C00003            Royal Equipments Works     Nashik     Maharashtra
# 3      C00004          Universal Equipments LLP  Ahmedabad         Gujarat
# 4      C00005            Metro Equipments Works     Bhopal  Madhya Pradesh
# 5      C00006  Sterling Systems Private Limited  Ahmedabad         Gujarat
# 6      C00007                 Royal Tools Works   Ludhiana          Punjab
# 7      C00008                  Galaxy Works Ltd       Pune     Maharashtra
# 8      C00009             Vertex Industries Ltd   Ludhiana          Punjab
# 9      C00010            Apex Enterprises Works     Mumbai     Maharashtra
#
#     region              industry customer_size segment  credit_days  \
# 0     West             Aerospace         Micro       D           15
# ...

# %% [markdown]
# ##3. Display last 10 rows.

# %%
import pandas as pd
customers = pd.read_csv(r"F:\Project Data Master\Asteron_Data_Lab_v1_Learner_Pack\raw\erp_customers.csv")
customers.tail(10)
# Out:
#      customer_id                    customer_name        city        state  \
# 5990      C05991           Indus Tools Industries    Ludhiana       Punjab
# 5991      C05992             Apex Solutions Works       Delhi        Delhi
# 5992      C05993        Fusion Industries Pvt Ltd        Pune  Maharashtra
# 5993      C05994                Apex Machines LLP        Pune  Maharashtra
# 5994      C05995         Kinetic Machines Pvt Ltd        Pune  Maharashtra
# 5995      C05996            Kinetic Works Pvt Ltd        Pune  Maharashtra
# 5996      C05997         Western Tools Industries   Bengaluru    Karnataka
# 5997      C05998  Dynamic Technologies Industries  Coimbatore   Tamil Nadu
# 5998      C05999            Metro Solutions Works   Ahmedabad      Gujarat
# 5999      C06000         Western Industries Works     Chennai   Tamil Nadu
#
#      region           industry customer_size segment  credit_days  \
# 5990  North         Renewables         Large       A           60
# ...

# %% [markdown]
# ##4. Show shape of the DataFrame.

# %%
customers.shape
# Out:
# (6000, 12)

# %% [markdown]
# ##5. List column names.

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'city', 'state', 'region', 'industry',
#        'customer_size', 'segment', 'credit_days', 'sales_rep_id',
#        'created_date', 'credit_limit_lakh'],
#       dtype='object')

# %%
for column in customers.columns:
    print(column)
# Out:
# customer_id
# customer_name
# city
# state
# region
# industry
# customer_size
# segment
# credit_days
# sales_rep_id
# created_date
# credit_limit_lakh

# %%
pd.DataFrame(customers.columns, columns=["Columns"])
# Out:
#               Columns
# 0         customer_id
# 1       customer_name
# 2                city
# 3               state
# 4              region
# 5            industry
# 6       customer_size
# 7             segment
# 8         credit_days
# 9        sales_rep_id
# 10       created_date
# 11  credit_limit_lakh

# %% [markdown]
# ##6. Inspect dtypes.

# %%
customers.dtypes.reset_index().rename(columns={"index":"Columns",0:"Data Type"})
# Out:
#               Columns Data Type
# 0         customer_id    object
# 1       customer_name    object
# 2                city    object
# 3               state    object
# 4              region    object
# 5            industry    object
# 6       customer_size    object
# 7             segment    object
# 8         credit_days     int64
# 9        sales_rep_id    object
# 10       created_date    object
# 11  credit_limit_lakh   float64

# %% [markdown]
# ##7. Use info() to inspect missing values.

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        6000 non-null   object
#  1   customer_name      6000 non-null   object
#  2   city               6000 non-null   object
#  3   state              6000 non-null   object
#  4   region             6000 non-null   object
#  5   industry           6000 non-null   object
#  6   customer_size      6000 non-null   object
#  7   segment            6000 non-null   object
#  8   credit_days        6000 non-null   int64
#  9   sales_rep_id       6000 non-null   object
#  10  created_date       6000 non-null   object
#  11  credit_limit_lakh  6000 non-null   float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 562.6+ KB

# %% [markdown]
# ##8. Generate descriptive statistics.

# %%
customers.head()
# Out:
#   customer_id             customer_name       city           state   region  \
# 0      C00001   Trinity Fasteners Works     Nashik     Maharashtra     West
# 1      C00002        Nova Fasteners Ltd  Bengaluru       Karnataka    South
# 2      C00003    Royal Equipments Works     Nashik     Maharashtra     West
# 3      C00004  Universal Equipments LLP  Ahmedabad         Gujarat     West
# 4      C00005    Metro Equipments Works     Bhopal  Madhya Pradesh  Central
#
#                industry customer_size segment  credit_days sales_rep_id  \
# 0             Aerospace         Micro       D           15        SR029
# 1            Automotive         Small       C           30        SR005
# 2            Electrical         Small       C           30        SR029
# 3  Industrial Machinery         Micro       D           15        SR001
# 4          Construction         Small       C           30        SR036
#
#   created_date  credit_limit_lakh
# 0   2021-06-09              12.02
# ...

# %%
customers.describe()
# Out:
#        credit_days  credit_limit_lakh
# count  6000.000000        6000.000000
# mean     35.287500         219.377243
# std      17.015525         373.959048
# min      15.000000           2.010000
# 25%      15.000000          43.487500
# 50%      30.000000          87.365000
# 75%      45.000000         221.152500
# max      75.000000        2796.730000

# %%
customers.describe(include="all")
# Out:
#        customer_id                   customer_name  city        state region  \
# count         6000                            6000  6000         6000   6000
# unique        6000                            2535    20           11      5
# top         C05984  Sigma Manufacturing Industries  Pune  Maharashtra   West
# freq             1                               8   935         2367   2840
# mean           NaN                             NaN   NaN          NaN    NaN
# std            NaN                             NaN   NaN          NaN    NaN
# min            NaN                             NaN   NaN          NaN    NaN
# 25%            NaN                             NaN   NaN          NaN    NaN
# 50%            NaN                             NaN   NaN          NaN    NaN
# 75%            NaN                             NaN   NaN          NaN    NaN
# max            NaN                             NaN   NaN          NaN    NaN
#
# ...

# %% [markdown]
# ##9. Select customer_id and customer_name.

# %%
customers[["customer_id","customer_name"]]
# Out:
#      customer_id                    customer_name
# 0         C00001          Trinity Fasteners Works
# 1         C00002               Nova Fasteners Ltd
# 2         C00003           Royal Equipments Works
# 3         C00004         Universal Equipments LLP
# 4         C00005           Metro Equipments Works
# ...          ...                              ...
# 5995      C05996            Kinetic Works Pvt Ltd
# 5996      C05997         Western Tools Industries
# 5997      C05998  Dynamic Technologies Industries
# 5998      C05999            Metro Solutions Works
# 5999      C06000         Western Industries Works
#
# [6000 rows x 2 columns]

# %% [markdown]
# ##10. Filter Pune customers.

# %%
customers[customers['city'] =="Pune"]
# Out:
#      customer_id                       customer_name  city        state  \
# 7         C00008                    Galaxy Works Ltd  Pune  Maharashtra
# 16        C00017            Supreme Works Industries  Pune  Maharashtra
# 27        C00028        Reliable Engineering Pvt Ltd  Pune  Maharashtra
# 32        C00033               Zenith Equipments Ltd  Pune  Maharashtra
# 33        C00034  Galaxy Engineering Private Limited  Pune  Maharashtra
# ...          ...                                 ...   ...          ...
# 5988      C05989           Bharat Auto Parts Pvt Ltd  Pune  Maharashtra
# 5992      C05993           Fusion Industries Pvt Ltd  Pune  Maharashtra
# 5993      C05994                   Apex Machines LLP  Pune  Maharashtra
# 5994      C05995            Kinetic Machines Pvt Ltd  Pune  Maharashtra
# 5995      C05996               Kinetic Works Pvt Ltd  Pune  Maharashtra
#
#      region           industry customer_size segment  credit_days  \
# ...

# %% [markdown]
# ##11. Filter Maharashtra customers.

# %%
customers[customers["state"] == "Maharashtra"]
# Out:
#      customer_id              customer_name    city        state region  \
# 0         C00001    Trinity Fasteners Works  Nashik  Maharashtra   West
# 2         C00003     Royal Equipments Works  Nashik  Maharashtra   West
# 7         C00008           Galaxy Works Ltd    Pune  Maharashtra   West
# 9         C00010     Apex Enterprises Works  Mumbai  Maharashtra   West
# 12        C00013    Trinity Enterprises Ltd  Mumbai  Maharashtra   West
# ...          ...                        ...     ...          ...    ...
# 5988      C05989  Bharat Auto Parts Pvt Ltd    Pune  Maharashtra   West
# 5992      C05993  Fusion Industries Pvt Ltd    Pune  Maharashtra   West
# 5993      C05994          Apex Machines LLP    Pune  Maharashtra   West
# 5994      C05995   Kinetic Machines Pvt Ltd    Pune  Maharashtra   West
# 5995      C05996      Kinetic Works Pvt Ltd    Pune  Maharashtra   West
#
#                  industry customer_size segment  credit_days sales_rep_id  \
# ...

# %% [markdown]
# ##12. Filter Large and Enterprise customers.

# %%
customers[customers["customer_size"].isin([ "Large","Enterprise"])]
# Out:
#      customer_id                     customer_name       city           state  \
# 5         C00006  Sterling Systems Private Limited  Ahmedabad         Gujarat
# 13        C00014         Supreme Solutions Pvt Ltd     Bhopal  Madhya Pradesh
# 22        C00023       Universal Manufacturing Ltd  Bengaluru       Karnataka
# 25        C00026              Bharat Tools Pvt Ltd  Ahmedabad         Gujarat
# 26        C00027               Vertex Projects Ltd     Indore  Madhya Pradesh
# ...          ...                               ...        ...             ...
# 5985      C05986           Bharat Industries Works    Kolkata     West Bengal
# 5987      C05988          Mahalaxmi Components Ltd     Indore  Madhya Pradesh
# 5990      C05991            Indus Tools Industries   Ludhiana          Punjab
# 5992      C05993         Fusion Industries Pvt Ltd       Pune     Maharashtra
# 5998      C05999             Metro Solutions Works  Ahmedabad         Gujarat
#
# ...

# %% [markdown]
# ##13. Sort customers by credit limit

# %%
customers.sort_values("credit_limit_lakh",ascending=False)
# Out:
#      customer_id                       customer_name       city        state  \
# 2334      C02335                   Trinity Works LLP  Bengaluru    Karnataka
# 2568      C02569               Om Industries Pvt Ltd       Pune  Maharashtra
# 354       C00355  Sterling Solutions Private Limited      Delhi        Delhi
# 390       C00391          Vertex Projects Industries     Mumbai  Maharashtra
# 4677      C04678           Sterling Equipments Works       Pune  Maharashtra
# ...          ...                                 ...        ...          ...
# 4348      C04349    Mahalaxmi Enterprises Industries      Delhi        Delhi
# 487       C00488                 Trinity Systems Ltd     Mumbai  Maharashtra
# 2651      C02652                Bharat Solutions LLP       Pune  Maharashtra
# 3376      C03377              Fusion Fabricators LLP     Jaipur    Rajasthan
# 1440      C01441          Western Industries Pvt Ltd     Rajkot      Gujarat
#
# ...

# %% [markdown]
# ##14. Find unique industries.

# %%
pd.DataFrame(customers["industry"].unique(),columns=["Industry"])
# Out:
#                Industry
# 0             Aerospace
# 1            Automotive
# 2            Electrical
# 3  Industrial Machinery
# 4          Construction
# 5   General Engineering
# 6            Renewables
# 7           Fabrication
# 8              Railways
# 9     Consumer Durables

# %% [markdown]
# ##15. Count customers by region.

# %%
customers.groupby("region").size().reset_index().rename(columns={'region':'Region',0:'Total'})
# Out:
#     Region  Total
# 0  Central    747
# 1     East    143
# 2    North   1290
# 3    South    980
# 4     West   2840

# %% [markdown]
# ##16. Calculate average credit days by size.

# %%
customers.head()
# Out:
#   customer_id             customer_name       city           state   region  \
# 0      C00001   Trinity Fasteners Works     Nashik     Maharashtra     West
# 1      C00002        Nova Fasteners Ltd  Bengaluru       Karnataka    South
# 2      C00003    Royal Equipments Works     Nashik     Maharashtra     West
# 3      C00004  Universal Equipments LLP  Ahmedabad         Gujarat     West
# 4      C00005    Metro Equipments Works     Bhopal  Madhya Pradesh  Central
#
#                industry customer_size segment  credit_days sales_rep_id  \
# 0             Aerospace         Micro       D           15        SR029
# 1            Automotive         Small       C           30        SR005
# 2            Electrical         Small       C           30        SR029
# 3  Industrial Machinery         Micro       D           15        SR001
# 4          Construction         Small       C           30        SR036
#
#   created_date  credit_limit_lakh
# 0   2021-06-09              12.02
# ...

# %%
customers.groupby('customer_size')['credit_days'].mean().reset_index(name='Average Credit Days').sort_values('Average Credit Days',ascending=False)
# Out:
#   customer_size  Average Credit Days
# 0    Enterprise                 75.0
# 1         Large                 60.0
# 2        Medium                 45.0
# 4         Small                 30.0
# 3         Micro                 15.0

# %% [markdown]
# ##17. Load products.

# %%
products =pd.read_csv(r"F:\Project Data Master\Asteron_Data_Lab_v1_Learner_Pack\raw\erp_products.csv")
products.head()
# Out:
#   product_id                     product_name             category material  \
# 0      P0001            Hex Bolts SS304 M8x50            Hex Bolts    SS304
# 1      P0002    Special Fasteners SS304 M8x40    Special Fasteners    SS304
# 2      P0003  Self Tapping Screws SS304 M8x25  Self Tapping Screws    SS304
# 3      P0004              Hex Bolts MS M12x40            Hex Bolts       MS
# 4      P0005      Special Fasteners MS M10x30    Special Fasteners       MS
#
#    diameter_mm  length_mm primary_supplier_id  standard_cost  list_price  uom
# 0            8         50                S012          10.76       16.51  PCS
# 1            8         40                S068           4.73        6.09  PCS
# 2            8         25                S084          12.06       17.28  BOX
# 3           12         40                S084           4.19        5.74  PCS
# 4           10         30                S036          14.97       19.63  PCS

# %% [markdown]
# ##18. Find products above a chosen price threshold.

# %%
products[products['list_price'] > 20].sort_values('list_price',ascending=False)
# Out:
#     product_id                              product_name  \
# 790      P0791  Industrial Consumables Alloy Steel M6x10
# 613      P0614                         Anchors MS M16x25
# 42       P0043                Socket Screws SS316 M20x30
# 695      P0696          Socket Screws Alloy Steel M16x16
# 888      P0889                Cutting Tools Brass M10x40
# ..         ...                                       ...
# 148      P0149                         Nuts SS304 M20x30
# 944      P0945                       Hex Bolts MS M24x25
# 402      P0403            Special Fasteners SS304 M10x25
# 254      P0255                         Anchors MS M10x50
# 345      P0346                Special Fasteners MS M5x30
#
#                    category     material  diameter_mm  length_mm  \
# 790  Industrial Consumables  Alloy Steel            6         10
# 613                 Anchors           MS           16         25
# 42            Socket Screws        SS316           20         30
# ...

# %% [markdown]
# ##19. Count products by category.

# %%
products.groupby('category').size().reset_index().rename(columns={'category':'Category',0:'No. Of Items'}).sort_values('No. Of Items')
# Out:
#                  Category  No. Of Items
# 1           Cutting Tools            58
# 8           Threaded Rods            68
# 5     Self Tapping Screws            75
# 0                 Anchors            75
# 3  Industrial Consumables            82
# 7       Special Fasteners            91
# 9                 Washers           101
# 4                    Nuts           116
# 6           Socket Screws           141
# 2               Hex Bolts           193

# %% [markdown]
# ##20. Calculate average list price by category.

# %%
products.groupby('category')['list_price'].mean().reset_index(name='List Price Average')
# Out:
#                  category  List Price Average
# 0                 Anchors           17.011467
# 1           Cutting Tools           17.898793
# 2               Hex Bolts           17.404041
# 3  Industrial Consumables           16.691707
# 4                    Nuts           17.190948
# 5     Self Tapping Screws           14.287067
# 6           Socket Screws           16.366099
# 7       Special Fasteners           15.767582
# 8           Threaded Rods           18.535882
# 9                 Washers           18.127624
